# %%
import pandas as pd
import numpy as np
import seaborn as sns
import regex as re
import misfunciones as mf

# %%
sharks = pd.read_csv("data/sharks.csv")

# %%
sharks
# Out:
#       Unnamed: 0        Type             Country               Area  \
# 0              0        Boat                 USA         California
# 1              1  Unprovoked                 USA            Georgia
# 2              3  Unprovoked           AUSTRALIA    New South Wales
# 3              4    Provoked              MEXICO             Colima
# 4              5  Unprovoked           AUSTRALIA    New South Wales
# ...          ...         ...                 ...                ...
# 5750        6297  Unprovoked           AUSTRALIA  Western Australia
# 5751        6298  Unprovoked           AUSTRALIA  Western Australia
# 5752        6299  Unprovoked                 USA     North Carolina
# 5753        6300  Unprovoked              PANAMA            UNKNOWN
# 5754        6301  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                    Activity Sex      Age Fatal       Species_02 Year_D  \
# 0     Paddling and similars   F       57     N      White shark   2018
# ...
